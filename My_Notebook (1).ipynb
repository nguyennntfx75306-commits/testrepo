# %%
1+1
# Out:
# 2

# %%
3+5
# Out:
# 8

# %%
123+568
# Out:
# 691

# %% [markdown]
# My Title

# %% [markdown]
# [Cognitive Class (Tầng lớp nhận thức)](https://cognitiveclass.ai/)

# %% [markdown]
# # Header 1

# %% [markdown]
# |Header|Header|
# |-----|------|
# |cell|cell|

# %% [markdown]
# |Hàng\Cột|Cột 2|Cột 3|
# |-----|-----|-----|
# |Hàng 1|Hàng 1|Hàng 1|
# |Hàng 2|Hàng 2|Hàng 2|
# |Hàng 3|Hàng 3|Hàng 3|
